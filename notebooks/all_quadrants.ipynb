# %%
from IPython.display import Image
# %matplotlib inline

# %%
filelist=!ls *png
filelist
# Out:
# ['wntn_fourplot_theta.png',
#  'wntn_fourplot_wvel.png',
#  'wntp_fourplot_theta.png',
#  'wntp_fourplot_wvel.png',
#  'wptn_fourplot_theta.png',
#  'wptn_fourplot_wvel.png',
#  'wptp_fourplot_theta.png',
#  'wptp_fourplot_wvel.png']

# %%
Image(filelist[0])

# %%
Image(filelist[1])

# %%
Image(filelist[2])

# %%
Image(filelist[3])

# %%
Image(filelist[4])

# %%
Image(filelist[5])

# %%
Image(filelist[6])

# %%
Image(filelist[7])
